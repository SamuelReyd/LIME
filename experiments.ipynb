# %%
from tqdm.notebook import tqdm
from collections import Counter
import matplotlib.pyplot as plt
import numpy as np
import json
import os
from env import *
from utils import *
from agent import *
from main import *

# %%
env = Environment.crate_maze("hard_maze")
agent = DQNAgent(env)
states, actions, rewards, agent = env.rollout(agent)

# %%
sample_ids = np.random.choice(np.arange(len(agent.buffer_replay)), size=10)
sample = np.array(agent.buffer_replay)[sample_ids]

# %%
states, actions, rewards, next_states = sample.T

# %%
np.array(list(map(lambda x: x.to_vect(), states)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/kh/yzswdk9578x_dpgwjvgznpt40000gn/T/ipykernel_26589/1902338799.py in <module>
# ----> 1 np.array(list(map(lambda x: x.to_vect(), states)))
#
# /var/folders/kh/yzswdk9578x_dpgwjvgznpt40000gn/T/ipykernel_26589/1902338799.py in <lambda>(x)
# ----> 1 np.array(list(map(lambda x: x.to_vect(), states)))
#
# AttributeError: 'State' object has no attribute 'to_vect'

# %%
agent = main("hard_maze", 200, 2000)
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]
